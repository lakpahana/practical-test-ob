# %%
import pandas as pd

# check all csv files in the directory

import os
report = []
for file in os.listdir():

    if file.endswith(".csv"):
        print(file)

        # read the csv file
        df = pd.read_csv(file)

        # check the first 5 rows of the data
        print(df.head())

        # check the last 5 rows of the data
        print(df.tail())

        # check the shape of the data
        print(df.shape)

        # check the data types of the columns
        print(df.dtypes)

        # check the column names
        print(df.columns)

        # check the summary statistics of the data
        print(df.describe())

        # check for missing values
        print(df.isnull().sum())

        # check for duplicated rows
        print(df.duplicated().sum())

        report.append({
            "summary": df.describe(),
            "missing": df.isnull().sum(),
            "duplicated": df.duplicated().sum()
        })

# save the report to a csv file
pd.DataFrame(report).to_csv("report.csv", index=False)
# Out:
# Ganison_dataset_1.csv
#                               school_name  year  StudentID    First Name  \
# 0  Christ King Catholic School, Bass Hill  2022          1  First Name 1
# 1  Christ King Catholic School, Bass Hill  2022          1  First Name 1
# 2  Christ King Catholic School, Bass Hill  2022          1  First Name 1
# 3  Christ King Catholic School, Bass Hill  2022          1  First Name 1
# 4  Christ King Catholic School, Bass Hill  2022          1  First Name 1
#
#      Last Name  Year Level    Class  Subject Answers Correct Answers  ...  \
# 0  Last Name 1           1  Class 1  Science       C               B  ...
# 1  Last Name 1           1  Class 1  Science       C               B  ...
# 2  Last Name 1           1  Class 1  Science       C               C  ...
# 3  Last Name 1           1  Class 1  Science       B               D  ...
# 4  Last Name 1           1  Class 1  Science       A               B  ...
#
#    correct_answer_percentage_per_class average_score school_percentile  \
# 0                                 3.04         60.39                81
# 1                                45.56         12.81                22
# 2                                48.49         20.34                53
# 3                                21.97          9.93                93
# 4                                70.32         39.01                68
#
#    sydney_percentile  strength_status  high_distinct_count  distinct_count  \
# 0                 77                E                   62              28
# 1                  4                E                   77               4
# 2                 25                E                   62              25
# 3                 72                E                   76              64
# 4                 92                E                   20              15
#
#    credit_count  participant_count          award
# 0            41                 34  Participation
# 1            88                 24  Participation
# 2            97                 44  Participation
# 3            77                 91  Participation
# 4            90                 59  Participation
#
# [5 rows x 31 columns]
#                                    school_name  year  StudentID  \
# 799995  Christ King Catholic School, Bass Hill  2022      16000
# 799996  Christ King Catholic School, Bass Hill  2022      16000
# 799997  Christ King Catholic School, Bass Hill  2022      16000
# 799998  Christ King Catholic School, Bass Hill  2022      16000
# 799999  Christ King Catholic School, Bass Hill  2022      16000
#
#               First Name        Last Name  Year Level    Class Subject  \
# 799995  First Name 16000  Last Name 16000           4  Class 4    Math
# 799996  First Name 16000  Last Name 16000           4  Class 4    Math
# 799997  First Name 16000  Last Name 16000           4  Class 4    Math
# 799998  First Name 16000  Last Name 16000           4  Class 4    Math
# 799999  First Name 16000  Last Name 16000           4  Class 4    Math
#
#        Answers Correct Answers  ...  correct_answer_percentage_per_class  \
# 799995       C               A  ...                                22.13
# 799996       C               D  ...                                35.07
# 799997       C               B  ...                                34.20
# 799998       A               Z  ...                                 7.67
# 799999       A               C  ...                                88.94
#
#        average_score school_percentile  sydney_percentile  strength_status  \
# 799995         78.60                72                 49                E
# 799996         28.82                22                 35                E
# 799997          1.18                42                 65                E
# 799998         78.06                10                 21                E
# 799999         93.57               100                 83                E
#
#         high_distinct_count  distinct_count  credit_count  participant_count  \
# 799995                   17              62            62                 39
# 799996                   68              64            61                 43
# 799997                   39              19            93                 85
# 799998                   85              96            95                 77
# 799999                   41              44            49                 49
#
#                 award
# 799995  Participation
# 799996  Participation
# 799997  Participation
# 799998  Participation
# 799999  Participation
#
# [5 rows x 31 columns]
# (800000, 31)
# school_name                             object
# year                                     int64
# StudentID                                int64
# First Name                              object
# Last Name                               object
# Year Level                               int64
# Class                                   object
# Subject                                 object
# Answers                                 object
# Correct Answers                         object
# Question Number                          int64
# Subject Contents                        object
# Assessment Areas                        object
# sydney_correct_count_percentage        float64
# sydney_average_score                   float64
# sydney_participants                      int64
# student_score                          float64
# student_total_assessed                   int64
# student_area_assessed_score            float64
# total_area_assessed_score              float64
# participant                              int64
# correct_answer_percentage_per_class    float64
# average_score                          float64
# school_percentile                        int64
# sydney_percentile                        int64
# strength_status                         object
# high_distinct_count                      int64
# distinct_count                           int64
# credit_count                             int64
# participant_count                        int64
# award                                   object
# dtype: object
# Index(['school_name', 'year', 'StudentID', 'First Name', 'Last Name',
#        'Year Level', 'Class', 'Subject', 'Answers', 'Correct Answers',
#        'Question Number', 'Subject Contents', 'Assessment Areas',
#        'sydney_correct_count_percentage', 'sydney_average_score',
#        'sydney_participants', 'student_score', 'student_total_assessed',
#        'student_area_assessed_score', 'total_area_assessed_score',
#        'participant', 'correct_answer_percentage_per_class', 'average_score',
#        'school_percentile', 'sydney_percentile', 'strength_status',
#        'high_distinct_count', 'distinct_count', 'credit_count',
#        'participant_count', 'award'],
#       dtype='object')
#            year      StudentID     Year Level  Question Number  \
# count  800000.0  800000.000000  800000.000000    800000.000000
# mean     2022.0    8000.500000       6.491562        13.000000
# std         0.0    4618.805031       3.442121         7.211107
# min      2022.0       1.000000       1.000000         1.000000
# 25%      2022.0    4000.750000       4.000000         7.000000
# 50%      2022.0    8000.500000       6.500000        13.000000
# 75%      2022.0   12000.250000       9.000000        19.000000
# max      2022.0   16000.000000      12.000000        25.000000
#
#        sydney_correct_count_percentage  sydney_average_score  \
# count                    800000.000000         800000.000000
# mean                         50.002762             49.996921
# std                          28.871401             28.867806
# min                           0.000000              0.000000
# 25%                          25.000000             24.960000
# 50%                          50.000000             50.020000
# 75%                          75.000000             74.970000
# max                         100.000000            100.000000
#
#        sydney_participants  student_score  student_total_assessed  \
# count        800000.000000  800000.000000           800000.000000
# mean             54.974225      50.015637               55.012504
# std              26.278214      28.857599               26.253684
# min              10.000000       0.000000               10.000000
# 25%              32.000000      25.030000               32.000000
# 50%              55.000000      50.030000               55.000000
# 75%              78.000000      75.010000               78.000000
# max             100.000000     100.000000              100.000000
#
#        student_area_assessed_score  total_area_assessed_score    participant  \
# count                800000.000000              800000.000000  800000.000000
# mean                     49.987962                  49.967346      55.005586
# std                      28.883495                  28.837838      26.239458
# min                       0.000000                   0.000000      10.000000
# 25%                      24.950000                  24.980000      32.000000
# 50%                      49.980000                  49.920000      55.000000
# 75%                      75.010000                  74.930000      78.000000
# max                     100.000000                 100.000000     100.000000
#
#        correct_answer_percentage_per_class  average_score  school_percentile  \
# count                        800000.000000  800000.000000      800000.000000
# mean                             50.014546      49.996848          50.506750
# std                              28.850701      28.878929          28.852988
# min                               0.000000       0.000000           1.000000
# 25%                              25.050000      24.990000          26.000000
# 50%                              50.010000      49.970000          50.000000
# 75%                              75.000000      75.010000          75.000000
# max                             100.000000     100.000000         100.000000
#
#        sydney_percentile  high_distinct_count  distinct_count   credit_count  \
# count      800000.000000        800000.000000   800000.000000  800000.000000
# mean           50.498029            50.552483       50.444415      50.487684
# std            28.866903            28.843751       28.867169      28.859805
# min             1.000000             1.000000        1.000000       1.000000
# 25%            25.000000            26.000000       25.000000      25.000000
# 50%            50.000000            51.000000       50.000000      51.000000
# 75%            76.000000            76.000000       75.000000      75.000000
# max           100.000000           100.000000      100.000000     100.000000
#
#        participant_count
# count      800000.000000
# mean           50.497451
# std            28.846328
# min             1.000000
# 25%            25.000000
# 50%            51.000000
# 75%            75.000000
# max           100.000000
# school_name                            0
# year                                   0
# StudentID                              0
# First Name                             0
# Last Name                              0
# Year Level                             0
# Class                                  0
# Subject                                0
# Answers                                0
# Correct Answers                        0
# Question Number                        0
# Subject Contents                       0
# Assessment Areas                       0
# sydney_correct_count_percentage        0
# sydney_average_score                   0
# sydney_participants                    0
# student_score                          0
# student_total_assessed                 0
# student_area_assessed_score            0
# total_area_assessed_score              0
# participant                            0
# correct_answer_percentage_per_class    0
# average_score                          0
# school_percentile                      0
# sydney_percentile                      0
# strength_status                        0
# high_distinct_count                    0
# distinct_count                         0
# credit_count                           0
# participant_count                      0
# award                                  0
# dtype: int64
# 0
# Ganison_dataset_2.csv
#                               school_name  year  StudentID    First Name  \
# 0  Christ King Catholic School, Bass Hill  2022          1  First Name 1
# 1  Christ King Catholic School, Bass Hill  2022          1  First Name 1
# 2  Christ King Catholic School, Bass Hill  2022          1  First Name 1
# 3  Christ King Catholic School, Bass Hill  2022          1  First Name 1
# 4  Christ King Catholic School, Bass Hill  2022          1  First Name 1
#
#      Last Name  Year Level    Class  Subject Answers Correct Answers  ...  \
# 0  Last Name 1           2  Class 2  History       D               C  ...
# 1  Last Name 1           2  Class 2  History       C               C  ...
# 2  Last Name 1           2  Class 2  History       D               B  ...
# 3  Last Name 1           2  Class 2  History       A               A  ...
# 4  Last Name 1           2  Class 2  History       A               A  ...
#
#    correct_answer_percentage_per_class average_score school_percentile  \
# 0                                29.04         32.86                 6
# 1                                37.81         15.23                96
# 2                                69.54         11.70                77
# 3                                86.83         95.92                17
# 4                                39.44          9.67                95
#
#    sydney_percentile  strength_status  high_distinct_count  distinct_count  \
# 0                 40                W                   51              90
# 1                 44                W                   64              86
# 2                  1                W                   21              23
# 3                 23                W                   58              12
# 4                 14                W                   41              19
#
#    credit_count  participant_count   award
# 0            33                 84  Credit
# 1            70                 88  Credit
# 2            47                 78  Credit
# 3            86                 91  Credit
# 4            11                 97  Credit
#
# [5 rows x 31 columns]
#                                    school_name  year  StudentID  \
# 799995  Christ King Catholic School, Bass Hill  2022      16000
# 799996  Christ King Catholic School, Bass Hill  2022      16000
# 799997  Christ King Catholic School, Bass Hill  2022      16000
# 799998  Christ King Catholic School, Bass Hill  2022      16000
# 799999  Christ King Catholic School, Bass Hill  2022      16000
#
#               First Name        Last Name  Year Level    Class  Subject  \
# 799995  First Name 16000  Last Name 16000           6  Class 6  English
# 799996  First Name 16000  Last Name 16000           6  Class 6  English
# 799997  First Name 16000  Last Name 16000           6  Class 6  English
# 799998  First Name 16000  Last Name 16000           6  Class 6  English
# 799999  First Name 16000  Last Name 16000           6  Class 6  English
#
#        Answers Correct Answers  ...  correct_answer_percentage_per_class  \
# 799995       A               C  ...                                25.51
# 799996       A               Z  ...                                10.18
# 799997       B               B  ...                                83.56
# 799998       A               B  ...                                32.52
# 799999       D               D  ...                                66.00
#
#        average_score school_percentile  sydney_percentile  strength_status  \
# 799995         40.48                20                 18                W
# 799996         53.73                97                 75                W
# 799997         32.65                24                  9                W
# 799998          4.51                59                 69                W
# 799999         42.68                 9                 95                W
#
#         high_distinct_count  distinct_count  credit_count  participant_count  \
# 799995                   35              19            75                 72
# 799996                   30              34            19                 11
# 799997                   73              40            74                 51
# 799998                   13              64            31                  5
# 799999                   59              20            29                 35
#
#          award
# 799995  Credit
# 799996  Credit
# 799997  Credit
# 799998  Credit
# 799999  Credit
#
# [5 rows x 31 columns]
# (800000, 31)
# school_name                             object
# year                                     int64
# StudentID                                int64
# First Name                              object
# Last Name                               object
# Year Level                               int64
# Class                                   object
# Subject                                 object
# Answers                                 object
# Correct Answers                         object
# Question Number                          int64
# Subject Contents                        object
# Assessment Areas                        object
# sydney_correct_count_percentage        float64
# sydney_average_score                   float64
# sydney_participants                      int64
# student_score                          float64
# student_total_assessed                   int64
# student_area_assessed_score            float64
# total_area_assessed_score              float64
# participant                              int64
# correct_answer_percentage_per_class    float64
# average_score                          float64
# school_percentile                        int64
# sydney_percentile                        int64
# strength_status                         object
# high_distinct_count                      int64
# distinct_count                           int64
# credit_count                             int64
# participant_count                        int64
# award                                   object
# dtype: object
# Index(['school_name', 'year', 'StudentID', 'First Name', 'Last Name',
#        'Year Level', 'Class', 'Subject', 'Answers', 'Correct Answers',
#        'Question Number', 'Subject Contents', 'Assessment Areas',
#        'sydney_correct_count_percentage', 'sydney_average_score',
#        'sydney_participants', 'student_score', 'student_total_assessed',
#        'student_area_assessed_score', 'total_area_assessed_score',
#        'participant', 'correct_answer_percentage_per_class', 'average_score',
#        'school_percentile', 'sydney_percentile', 'strength_status',
#        'high_distinct_count', 'distinct_count', 'credit_count',
#        'participant_count', 'award'],
#       dtype='object')
#            year      StudentID     Year Level  Question Number  \
# count  800000.0  800000.000000  800000.000000    800000.000000
# mean     2022.0    8000.500000       6.452562        13.000000
# std         0.0    4618.805031       3.463887         7.211107
# min      2022.0       1.000000       1.000000         1.000000
# 25%      2022.0    4000.750000       3.000000         7.000000
# 50%      2022.0    8000.500000       6.000000        13.000000
# 75%      2022.0   12000.250000       9.000000        19.000000
# max      2022.0   16000.000000      12.000000        25.000000
#
#        sydney_correct_count_percentage  sydney_average_score  \
# count                    800000.000000         800000.000000
# mean                         49.996598             49.952699
# std                          28.866492             28.871227
# min                           0.000000              0.000000
# 25%                          25.030000             24.960000
# 50%                          49.970000             49.960000
# 75%                          74.990000             74.890000
# max                         100.000000            100.000000
#
#        sydney_participants  student_score  student_total_assessed  \
# count         800000.00000  800000.000000           800000.000000
# mean              55.02782      49.995712               55.001375
# std               26.28256      28.875230               26.256860
# min               10.00000       0.000000               10.000000
# 25%               32.00000      24.980000               32.000000
# 50%               55.00000      49.960000               55.000000
# 75%               78.00000      74.990000               78.000000
# max              100.00000     100.000000              100.000000
#
#        student_area_assessed_score  total_area_assessed_score    participant  \
# count                800000.000000              800000.000000  800000.000000
# mean                     49.977589                  49.984075      55.040665
# std                      28.868691                  28.849671      26.283561
# min                       0.000000                   0.000000      10.000000
# 25%                      24.950000                  25.030000      32.000000
# 50%                      49.990000                  49.950000      55.000000
# 75%                      74.960000                  74.980000      78.000000
# max                     100.000000                 100.000000     100.000000
#
#        correct_answer_percentage_per_class  average_score  school_percentile  \
# count                        800000.000000  800000.000000      800000.000000
# mean                             50.034653      49.956620          50.515629
# std                              28.859050      28.859999          28.865615
# min                               0.000000       0.000000           1.000000
# 25%                              25.070000      24.970000          26.000000
# 50%                              50.050000      49.920000          51.000000
# 75%                              75.020000      74.950000          76.000000
# max                             100.000000     100.000000         100.000000
#
#        sydney_percentile  high_distinct_count  distinct_count   credit_count  \
# count      800000.000000        800000.000000   800000.000000  800000.000000
# mean           50.526284            50.482256       50.468011      50.493491
# std            28.858049            28.861768       28.857126      28.865648
# min             1.000000             1.000000        1.000000       1.000000
# 25%            26.000000            25.000000       25.000000      26.000000
# 50%            51.000000            50.000000       50.000000      50.000000
# 75%            75.000000            75.000000       75.000000      76.000000
# max           100.000000           100.000000      100.000000     100.000000
#
#        participant_count
# count      800000.000000
# mean           50.531471
# std            28.865492
# min             1.000000
# 25%            26.000000
# 50%            50.000000
# 75%            76.000000
# max           100.000000
# school_name                            0
# year                                   0
# StudentID                              0
# First Name                             0
# Last Name                              0
# Year Level                             0
# Class                                  0
# Subject                                0
# Answers                                0
# Correct Answers                        0
# Question Number                        0
# Subject Contents                       0
# Assessment Areas                       0
# sydney_correct_count_percentage        0
# sydney_average_score                   0
# sydney_participants                    0
# student_score                          0
# student_total_assessed                 0
# student_area_assessed_score            0
# total_area_assessed_score              0
# participant                            0
# correct_answer_percentage_per_class    0
# average_score                          0
# school_percentile                      0
# sydney_percentile                      0
# strength_status                        0
# high_distinct_count                    0
# distinct_count                         0
# credit_count                           0
# participant_count                      0
# award                                  0
# dtype: int64
# 0
# ganison_dataset_3.csv
#                               school_name  year  StudentID    First Name  \
# 0  Christ King Catholic School, Bass Hill  2022          1  First Name 1
# 1  Christ King Catholic School, Bass Hill  2022          1  First Name 1
# 2  Christ King Catholic School, Bass Hill  2022          1  First Name 1
# 3  Christ King Catholic School, Bass Hill  2022          1  First Name 1
# 4  Christ King Catholic School, Bass Hill  2022          1  First Name 1
#
#      Last Name  Year Level    Class Subject Answers Correct Answers  ...  \
# 0  Last Name 1           2  Class 2     Art       C               Z  ...
# 1  Last Name 1           2  Class 2     Art       C               C  ...
# 2  Last Name 1           2  Class 2     Art       C               C  ...
# 3  Last Name 1           2  Class 2     Art       C               C  ...
# 4  Last Name 1           2  Class 2     Art       C               Z  ...
#
#    correct_answer_percentage_per_class average_score school_percentile  \
# 0                                76.65         54.76                85
# 1                                 4.16         28.05                29
# 2                                 5.16         66.37                33
# 3                                75.54         49.93                14
# 4                                 0.45         52.92                93
#
#    sydney_percentile  strength_status  high_distinct_count  distinct_count  \
# 0                 61                W                   80              51
# 1                 25                W                   23              74
# 2                 40                W                   92              76
# 3                 69                W                   19              80
# 4                 23                W                    7              64
#
#    credit_count  participant_count  awarDistinction
# 0            25                 97      Distinction
# 1            85                 89      Distinction
# 2            22                  5      Distinction
# 3             5                 68      Distinction
# 4            79                 60      Distinction
#
# [5 rows x 31 columns]
#                                    school_name  year  StudentID  \
# 799995  Christ King Catholic School, Bass Hill  2022      16000
# 799996  Christ King Catholic School, Bass Hill  2022      16000
# 799997  Christ King Catholic School, Bass Hill  2022      16000
# 799998  Christ King Catholic School, Bass Hill  2022      16000
# 799999  Christ King Catholic School, Bass Hill  2022      16000
#
#               First Name        Last Name  Year Level     Class Subject  \
# 799995  First Name 16000  Last Name 16000          12  Class 12   Music
# 799996  First Name 16000  Last Name 16000          12  Class 12   Music
# 799997  First Name 16000  Last Name 16000          12  Class 12   Music
# 799998  First Name 16000  Last Name 16000          12  Class 12   Music
# 799999  First Name 16000  Last Name 16000          12  Class 12   Music
#
#        Answers Correct Answers  ...  correct_answer_percentage_per_class  \
# 799995       C               Z  ...                                68.34
# 799996       D               Z  ...                                87.39
# 799997       B               Z  ...                                45.80
# 799998       A               Z  ...                                46.12
# 799999       A               A  ...                                 1.59
#
#        average_score school_percentile  sydney_percentile  strength_status  \
# 799995          5.29                59                 80                W
# 799996         18.37                14                 70                W
# 799997         41.75                 3                 74                W
# 799998         30.95                73                 37                W
# 799999         31.61                47                 16                W
#
#         high_distinct_count  distinct_count  credit_count  participant_count  \
# 799995                   87              74            92                  3
# 799996                   39              88            13                 50
# 799997                   56              27            18                 14
# 799998                   20              25            10                 89
# 799999                   87              79            33                 24
#
#         awarDistinction
# 799995      Distinction
# 799996      Distinction
# 799997      Distinction
# 799998      Distinction
# 799999      Distinction
#
# [5 rows x 31 columns]
# (800000, 31)
# school_name                             object
# year                                     int64
# StudentID                                int64
# First Name                              object
# Last Name                               object
# Year Level                               int64
# Class                                   object
# Subject                                 object
# Answers                                 object
# Correct Answers                         object
# Question Number                          int64
# Subject Contents                        object
# Assessment Areas                        object
# sydney_correct_count_percentage        float64
# sydney_average_score                   float64
# sydney_participants                      int64
# student_score                          float64
# student_total_assessed                   int64
# student_area_assessed_score            float64
# total_area_assessed_score              float64
# participant                              int64
# correct_answer_percentage_per_class    float64
# average_score                          float64
# school_percentile                        int64
# sydney_percentile                        int64
# strength_status                         object
# high_distinct_count                      int64
# distinct_count                           int64
# credit_count                             int64
# participant_count                        int64
# awarDistinction                         object
# dtype: object
# Index(['school_name', 'year', 'StudentID', 'First Name', 'Last Name',
#        'Year Level', 'Class', 'Subject', 'Answers', 'Correct Answers',
#        'Question Number', 'Subject Contents', 'Assessment Areas',
#        'sydney_correct_count_percentage', 'sydney_average_score',
#        'sydney_participants', 'student_score', 'student_total_assessed',
#        'student_area_assessed_score', 'total_area_assessed_score',
#        'participant', 'correct_answer_percentage_per_class', 'average_score',
#        'school_percentile', 'sydney_percentile', 'strength_status',
#        'high_distinct_count', 'distinct_count', 'credit_count',
#        'participant_count', 'awarDistinction'],
#       dtype='object')
#            year      StudentID     Year Level  Question Number  \
# count  800000.0  800000.000000  800000.000000    800000.000000
# mean     2022.0    8000.500000       6.482125        13.000000
# std         0.0    4618.805031       3.439923         7.211107
# min      2022.0       1.000000       1.000000         1.000000
# 25%      2022.0    4000.750000       4.000000         7.000000
# 50%      2022.0    8000.500000       6.000000        13.000000
# 75%      2022.0   12000.250000       9.000000        19.000000
# max      2022.0   16000.000000      12.000000        25.000000
#
#        sydney_correct_count_percentage  sydney_average_score  \
# count                    800000.000000         800000.000000
# mean                         49.979454             50.011524
# std                          28.887099             28.849732
# min                           0.000000              0.000000
# 25%                          24.940000             25.010000
# 50%                          50.000000             50.020000
# 75%                          75.030000             74.960000
# max                         100.000000            100.000000
#
#        sydney_participants  student_score  student_total_assessed  \
# count        800000.000000  800000.000000           800000.000000
# mean             54.972156      49.957794               54.956700
# std              26.279436      28.855342               26.266038
# min              10.000000       0.000000               10.000000
# 25%              32.000000      24.990000               32.000000
# 50%              55.000000      49.990000               55.000000
# 75%              78.000000      74.910000               78.000000
# max             100.000000     100.000000              100.000000
#
#        student_area_assessed_score  total_area_assessed_score    participant  \
# count                800000.000000              800000.000000  800000.000000
# mean                     50.009411                  49.960498      54.974715
# std                      28.859857                  28.860202      26.297447
# min                       0.000000                   0.000000      10.000000
# 25%                      25.000000                  24.980000      32.000000
# 50%                      50.020000                  49.950000      55.000000
# 75%                      75.010000                  74.940000      78.000000
# max                     100.000000                 100.000000     100.000000
#
#        correct_answer_percentage_per_class  average_score  school_percentile  \
# count                        800000.000000  800000.000000      800000.000000
# mean                             49.943051      50.028470          50.509660
# std                              28.887142      28.846509          28.874667
# min                               0.000000       0.000000           1.000000
# 25%                              24.870000      25.130000          25.000000
# 50%                              49.960000      50.040000          50.000000
# 75%                              74.940000      75.010000          76.000000
# max                             100.000000     100.000000         100.000000
#
#        sydney_percentile  high_distinct_count  distinct_count   credit_count  \
# count      800000.000000        800000.000000   800000.000000  800000.000000
# mean           50.451145            50.526724       50.527501      50.516936
# std            28.863513            28.861777       28.878339      28.861240
# min             1.000000             1.000000        1.000000       1.000000
# 25%            25.000000            26.000000       26.000000      26.000000
# 50%            50.000000            51.000000       51.000000      51.000000
# 75%            75.000000            76.000000       76.000000      75.000000
# max           100.000000           100.000000      100.000000     100.000000
#
#        participant_count
# count      800000.000000
# mean           50.523731
# std            28.885213
# min             1.000000
# 25%            25.000000
# 50%            51.000000
# 75%            76.000000
# max           100.000000
# school_name                            0
# year                                   0
# StudentID                              0
# First Name                             0
# Last Name                              0
# Year Level                             0
# Class                                  0
# Subject                                0
# Answers                                0
# Correct Answers                        0
# Question Number                        0
# Subject Contents                       0
# Assessment Areas                       0
# sydney_correct_count_percentage        0
# sydney_average_score                   0
# sydney_participants                    0
# student_score                          0
# student_total_assessed                 0
# student_area_assessed_score            0
# total_area_assessed_score              0
# participant                            0
# correct_answer_percentage_per_class    0
# average_score                          0
# school_percentile                      0
# sydney_percentile                      0
# strength_status                        0
# high_distinct_count                    0
# distinct_count                         0
# credit_count                           0
# participant_count                      0
# awarDistinction                        0
# dtype: int64
# 0
# ganison_dataset_4.csv
#                               school_name  year  StudentID    First Name  \
# 0  Christ King Catholic School, Bass Hill  2022          1  First Name 1
# 1  Christ King Catholic School, Bass Hill  2022          1  First Name 1
# 2  Christ King Catholic School, Bass Hill  2022          1  First Name 1
# 3  Christ King Catholic School, Bass Hill  2022          1  First Name 1
# 4  Christ King Catholic School, Bass Hill  2022          1  First Name 1
#
#      Last Name  Year Level    Class  Subject Answers Correct Answers  ...  \
# 0  Last Name 1           8  Class 8  History       C               ?  ...
# 1  Last Name 1           8  Class 8  History       B               ?  ...
# 2  Last Name 1           8  Class 8  History       B               B  ...
# 3  Last Name 1           8  Class 8  History       A               B  ...
# 4  Last Name 1           8  Class 8  History       D               C  ...
#
#    correct_answer_percentage_per_class average_score school_percentile  \
# 0                                81.31         88.83                80
# 1                                30.84         54.25                38
# 2                                68.22         46.24                98
# 3                                74.92         62.23                66
# 4                                53.51         54.21                78
#
#    sydney_percentile  strength_status  high_distinct_count  distinct_count  \
# 0                 15                S                   47              93
# 1                  3                S                   48              59
# 2                 76                S                    2              65
# 3                 60                S                   77              76
# 4                 78                S                   44              38
#
#    credit_count  participant_count   award
# 0            94                 88  Credit
# 1            54                 58  Credit
# 2            93                 27  Credit
# 3            97                 89  Credit
# 4            17                 82  Credit
#
# [5 rows x 31 columns]
#                                    school_name  year  StudentID  \
# 799995  Christ King Catholic School, Bass Hill  2022      16000
# 799996  Christ King Catholic School, Bass Hill  2022      16000
# 799997  Christ King Catholic School, Bass Hill  2022      16000
# 799998  Christ King Catholic School, Bass Hill  2022      16000
# 799999  Christ King Catholic School, Bass Hill  2022      16000
#
#               First Name        Last Name  Year Level    Class  Subject  \
# 799995  First Name 16000  Last Name 16000           4  Class 4  English
# 799996  First Name 16000  Last Name 16000           4  Class 4  English
# 799997  First Name 16000  Last Name 16000           4  Class 4  English
# 799998  First Name 16000  Last Name 16000           4  Class 4  English
# 799999  First Name 16000  Last Name 16000           4  Class 4  English
#
#        Answers Correct Answers  ...  correct_answer_percentage_per_class  \
# 799995       A               C  ...                                62.18
# 799996       C               ?  ...                                26.50
# 799997       A               D  ...                                56.74
# 799998       B               C  ...                                28.14
# 799999       A               C  ...                                67.23
#
#        average_score school_percentile  sydney_percentile  strength_status  \
# 799995          4.87                30                 45                S
# 799996         84.60                16                 47                S
# 799997         80.30                42                 44                S
# 799998         78.53                93                 36                S
# 799999         61.59                15                 50                S
#
#         high_distinct_count  distinct_count  credit_count  participant_count  \
# 799995                   40              99            45                  4
# 799996                    9              37            73                 17
# 799997                   38              81            71                 49
# 799998                   26              66            81                 14
# 799999                   44              37            64                 17
#
#          award
# 799995  Credit
# 799996  Credit
# 799997  Credit
# 799998  Credit
# 799999  Credit
#
# [5 rows x 31 columns]
# (800000, 31)
# school_name                             object
# year                                     int64
# StudentID                                int64
# First Name                              object
# Last Name                               object
# Year Level                               int64
# Class                                   object
# Subject                                 object
# Answers                                 object
# Correct Answers                         object
# Question Number                          int64
# Subject Contents                        object
# Assessment Areas                        object
# sydney_correct_count_percentage        float64
# sydney_average_score                   float64
# sydney_participants                      int64
# student_score                          float64
# student_total_assessed                   int64
# student_area_assessed_score            float64
# total_area_assessed_score              float64
# participant                              int64
# correct_answer_percentage_per_class    float64
# average_score                          float64
# school_percentile                        int64
# sydney_percentile                        int64
# strength_status                         object
# high_distinct_count                      int64
# distinct_count                           int64
# credit_count                             int64
# participant_count                        int64
# award                                   object
# dtype: object
# Index(['school_name', 'year', 'StudentID', 'First Name', 'Last Name',
#        'Year Level', 'Class', 'Subject', 'Answers', 'Correct Answers',
#        'Question Number', 'Subject Contents', 'Assessment Areas',
#        'sydney_correct_count_percentage', 'sydney_average_score',
#        'sydney_participants', 'student_score', 'student_total_assessed',
#        'student_area_assessed_score', 'total_area_assessed_score',
#        'participant', 'correct_answer_percentage_per_class', 'average_score',
#        'school_percentile', 'sydney_percentile', 'strength_status',
#        'high_distinct_count', 'distinct_count', 'credit_count',
#        'participant_count', 'award'],
#       dtype='object')
#            year      StudentID     Year Level  Question Number  \
# count  800000.0  800000.000000  800000.000000    800000.000000
# mean     2022.0    8000.500000       6.466000        38.000000
# std         0.0    4618.805031       3.445121         7.211107
# min      2022.0       1.000000       1.000000        26.000000
# 25%      2022.0    4000.750000       3.000000        32.000000
# 50%      2022.0    8000.500000       6.000000        38.000000
# 75%      2022.0   12000.250000       9.000000        44.000000
# max      2022.0   16000.000000      12.000000        50.000000
#
#        sydney_correct_count_percentage  sydney_average_score  \
# count                    800000.000000         800000.000000
# mean                         49.997054             49.993282
# std                          28.859071             28.843718
# min                           0.000000              0.000000
# 25%                          25.000000             25.010000
# 50%                          50.020000             50.040000
# 75%                          74.970000             74.950000
# max                         100.000000            100.000000
#
#        sydney_participants  student_score  student_total_assessed  \
# count        800000.000000  800000.000000           800000.000000
# mean             54.956083      50.062479               55.016311
# std              26.272504      28.850876               26.261964
# min              10.000000       0.000000               10.000000
# 25%              32.000000      25.110000               32.000000
# 50%              55.000000      50.050000               55.000000
# 75%              78.000000      75.050000               78.000000
# max             100.000000     100.000000              100.000000
#
#        student_area_assessed_score  total_area_assessed_score    participant  \
# count                800000.000000              800000.000000  800000.000000
# mean                     49.955761                  50.002605      54.953586
# std                      28.858976                  28.852630      26.291005
# min                       0.000000                   0.000000      10.000000
# 25%                      24.980000                  25.050000      32.000000
# 50%                      49.950000                  50.000000      55.000000
# 75%                      74.940000                  74.990000      78.000000
# max                     100.000000                 100.000000     100.000000
#
#        correct_answer_percentage_per_class  average_score  school_percentile  \
# count                        800000.000000  800000.000000      800000.000000
# mean                             50.014849      49.994594          50.466064
# std                              28.862240      28.856367          28.865916
# min                               0.000000       0.000000           1.000000
# 25%                              25.050000      25.010000          25.000000
# 50%                              49.990000      49.980000          50.000000
# 75%                              75.030000      74.980000          75.000000
# max                             100.000000     100.000000         100.000000
#
#        sydney_percentile  high_distinct_count  distinct_count   credit_count  \
# count      800000.000000        800000.000000   800000.000000  800000.000000
# mean           50.457891            50.543377       50.534880      50.469673
# std            28.880470            28.877236       28.879881      28.867296
# min             1.000000             1.000000        1.000000       1.000000
# 25%            25.000000            26.000000       26.000000      25.000000
# 50%            50.000000            51.000000       51.000000      50.000000
# 75%            75.000000            76.000000       76.000000      75.000000
# max           100.000000           100.000000      100.000000     100.000000
#
#        participant_count
# count      800000.000000
# mean           50.459043
# std            28.861222
# min             1.000000
# 25%            25.000000
# 50%            50.000000
# 75%            75.000000
# max           100.000000
# school_name                            0
# year                                   0
# StudentID                              0
# First Name                             0
# Last Name                              0
# Year Level                             0
# Class                                  0
# Subject                                0
# ...
#        student_area_assessed_score  total_area_assessed_score    participant  \
# count                800000.000000              800000.000000  800000.000000
# mean                     49.990550                  50.037746      54.981900
# std                      28.835239                  28.865301      26.273588
# min                       0.000000                   0.000000      10.000000
# 25%                      25.020000                  25.040000      32.000000
# 50%                      49.990000                  50.070000      55.000000
# 75%                      74.940000                  75.060000      78.000000
# max                     100.000000                 100.000000     100.000000
#
#        correct_answer_percentage_per_class  average_score  school_percentile  \
# count                        800000.000000  800000.000000      800000.000000
# mean                             49.980689      50.004320          50.514074
# std                              28.875103      28.853676          28.886097
# min                               0.000000       0.000000           1.000000
# 25%                              24.920000      25.020000          26.000000
# 50%                              49.930000      50.040000          50.000000
# 75%                              75.030000      74.980000          76.000000
# max                             100.000000     100.000000         100.000000
#
#        sydney_percentile  high_distinct_count  distinct_count   credit_count  \
# count      800000.000000        800000.000000   800000.000000  800000.000000
# mean           50.451939            50.506274       50.510886      50.532915
# std            28.881596            28.890480       28.847693      28.865237
# min             1.000000             1.000000        1.000000       1.000000
# 25%            25.000000            25.000000       26.000000      26.000000
# 50%            50.000000            51.000000       51.000000      51.000000
# 75%            75.000000            76.000000       75.000000      76.000000
# max           100.000000           100.000000      100.000000     100.000000
#
#        participant_count
# count      800000.000000
# mean           50.537164
# std            28.859680
# min             1.000000
# 25%            26.000000
# 50%            50.000000
# 75%            76.000000
# max           100.000000
# school_name                            0
# year                                   0
# StudentID                              0
# First Name                             0
# Last Name                              0
# Year Level                             0
# Class                                  0
# Subject                                0
# Answers                                0
# Correct Answers                        0
# Question Number                        0
# Subject Contents                       0
# Assessment Areas                       0
# sydney_correct_count_percentage        0
# sydney_average_score                   0
# sydney_participants                    0
# student_score                          0
# student_total_assessed                 0
# student_area_assessed_score            0
# total_area_assessed_score              0
# participant                            0
# correct_answer_percentage_per_class    0
# average_score                          0
# school_percentile                      0
# sydney_percentile                      0
# strength_status                        0
# high_distinct_count                    0
# distinct_count                         0
# credit_count                           0
# participant_count                      0
# award                                  0
# dtype: int64
# 0
# ganison_dataset_6.csv
#                               school_name  year  StudentID    First Name  \
# 0  Christ King Catholic School, Bass Hill  2022          1  First Name 1
# 1  Christ King Catholic School, Bass Hill  2022          1  First Name 1
# 2  Christ King Catholic School, Bass Hill  2022          1  First Name 1
# 3  Christ King Catholic School, Bass Hill  2022          1  First Name 1
# 4  Christ King Catholic School, Bass Hill  2022          1  First Name 1
#
#      Last Name  Year Level    Class  Subject Answers Correct Answers  ...  \
# 0  Last Name 1           2  Class 2  Science       D               ?  ...
# 1  Last Name 1           2  Class 2  Science       C               B  ...
# 2  Last Name 1           2  Class 2  Science       D               B  ...
# 3  Last Name 1           2  Class 2  Science       C               C  ...
# 4  Last Name 1           2  Class 2  Science       B               ?  ...
#
#    correct_answer_percentage_per_class average_score school_percentile  \
# 0                                72.28         16.06                28
# 1                                37.78         98.76                41
# 2                                30.10         62.61                63
# 3                                14.25         69.73                64
# 4                                20.87         35.11                95
#
#    sydney_percentile  strength_status  high_distinct_count  distinct_count  \
# 0                 47                -                   24              36
# 1                 20                -                    1               4
# 2                 40                -                   35              36
# 3                  6                -                   58              34
# 4                 77                -                   61              23
#
#    credit_count  participant_count             award
# 0             8                 25  High Distinction
# 1            90                 70  High Distinction
# 2            80                  6  High Distinction
# 3            98                 15  High Distinction
# 4            29                 40  High Distinction
#
# [5 rows x 31 columns]
#                                    school_name  year  StudentID  \
# 799995  Christ King Catholic School, Bass Hill  2022      16000
# 799996  Christ King Catholic School, Bass Hill  2022      16000
# 799997  Christ King Catholic School, Bass Hill  2022      16000
# 799998  Christ King Catholic School, Bass Hill  2022      16000
# 799999  Christ King Catholic School, Bass Hill  2022      16000
#
#               First Name        Last Name  Year Level     Class Subject  \
# 799995  First Name 16000  Last Name 16000          11  Class 11    Math
# 799996  First Name 16000  Last Name 16000          11  Class 11    Math
# 799997  First Name 16000  Last Name 16000          11  Class 11    Math
# 799998  First Name 16000  Last Name 16000          11  Class 11    Math
# 799999  First Name 16000  Last Name 16000          11  Class 11    Math
#
#        Answers Correct Answers  ...  correct_answer_percentage_per_class  \
# 799995       D               B  ...                                81.99
# 799996       C               ?  ...                                40.05
# 799997       D               C  ...                                43.54
# 799998       C               ?  ...                                49.03
# 799999       A               A  ...                                54.44
#
#        average_score school_percentile  sydney_percentile  strength_status  \
# 799995         46.37                68                 70                -
# 799996         48.52                55                 42                -
# 799997         32.56                83                 34                -
# 799998         60.76                74                 59                -
# 799999         10.79                11                 11                -
#
#         high_distinct_count  distinct_count  credit_count  participant_count  \
# 799995                   90               7            77                 20
# 799996                   57              56            67                 58
# 799997                    4              98            91                 22
# 799998                   17              84            65                 12
# 799999                   52              24            27                  7
#
#                    award
# 799995  High Distinction
# 799996  High Distinction
# 799997  High Distinction
# 799998  High Distinction
# 799999  High Distinction
#
# [5 rows x 31 columns]
# (800000, 31)
# school_name                             object
# year                                     int64
# StudentID                                int64
# First Name                              object
# Last Name                               object
# Year Level                               int64
# Class                                   object
# Subject                                 object
# Answers                                 object
# Correct Answers                         object
# Question Number                          int64
# Subject Contents                        object
# Assessment Areas                        object
# sydney_correct_count_percentage        float64
# sydney_average_score                   float64
# sydney_participants                      int64
# student_score                          float64
# student_total_assessed                   int64
# student_area_assessed_score            float64
# total_area_assessed_score              float64
# participant                              int64
# correct_answer_percentage_per_class    float64
# average_score                          float64
# school_percentile                        int64
# sydney_percentile                        int64
# strength_status                         object
# high_distinct_count                      int64
# distinct_count                           int64
# credit_count                             int64
# participant_count                        int64
# award                                   object
# dtype: object
# Index(['school_name', 'year', 'StudentID', 'First Name', 'Last Name',
#        'Year Level', 'Class', 'Subject', 'Answers', 'Correct Answers',
#        'Question Number', 'Subject Contents', 'Assessment Areas',
#        'sydney_correct_count_percentage', 'sydney_average_score',
#        'sydney_participants', 'student_score', 'student_total_assessed',
#        'student_area_assessed_score', 'total_area_assessed_score',
#        'participant', 'correct_answer_percentage_per_class', 'average_score',
#        'school_percentile', 'sydney_percentile', 'strength_status',
#        'high_distinct_count', 'distinct_count', 'credit_count',
#        'participant_count', 'award'],
#       dtype='object')
#            year      StudentID     Year Level  Question Number  \
# count  800000.0  800000.000000  800000.000000    800000.000000
# mean     2022.0    8000.500000       6.508500        38.000000
# std         0.0    4618.805031       3.458532         7.211107
# min      2022.0       1.000000       1.000000        26.000000
# 25%      2022.0    4000.750000       4.000000        32.000000
# 50%      2022.0    8000.500000       6.000000        38.000000
# 75%      2022.0   12000.250000      10.000000        44.000000
# max      2022.0   16000.000000      12.000000        50.000000
#
#        sydney_correct_count_percentage  sydney_average_score  \
# count                    800000.000000         800000.000000
# mean                         49.951136             49.972171
# std                          28.851814             28.882990
# min                           0.000000              0.000000
# 25%                          24.980000             24.980000
# 50%                          49.940000             49.980000
# 75%                          74.930000             74.980000
# max                         100.000000            100.000000
#
#        sydney_participants  student_score  student_total_assessed  \
# count        800000.000000  800000.000000           800000.000000
# mean             54.931334      49.960438               55.066571
# std              26.270403      28.866672               26.254268
# min              10.000000       0.000000               10.000000
# 25%              32.000000      24.920000               32.000000
# 50%              55.000000      49.950000               55.000000
# 75%              78.000000      74.990000               78.000000
# max             100.000000     100.000000              100.000000
#
#        student_area_assessed_score  total_area_assessed_score    participant  \
# count                800000.000000              800000.000000  800000.000000
# mean                     49.946831                  50.045202      54.976586
# std                      28.846190                  28.861219      26.250904
# min                       0.000000                   0.000000      10.000000
# 25%                      25.000000                  25.040000      32.000000
# 50%                      49.910000                  50.050000      55.000000
# 75%                      74.910000                  75.060000      78.000000
# max                     100.000000                 100.000000     100.000000
#
#        correct_answer_percentage_per_class  average_score  school_percentile  \
# count                        800000.000000  800000.000000      800000.000000
# mean                             49.968324      49.912758          50.562320
# std                              28.887145      28.881626          28.875945
# min                               0.000000       0.000000           1.000000
# 25%                              24.930000      24.870000          26.000000
# 50%                              49.940000      49.910000          51.000000
# 75%                              74.990000      74.930000          76.000000
# max                             100.000000     100.000000         100.000000
#
#        sydney_percentile  high_distinct_count  distinct_count   credit_count  \
# count      800000.000000        800000.000000   800000.000000  800000.000000
# mean           50.509791            50.516175       50.490359      50.526276
# std            28.868946            28.889199       28.880101      28.868068
# min             1.000000             1.000000        1.000000       1.000000
# 25%            26.000000            25.000000       25.000000      26.000000
# 50%            51.000000            51.000000       50.000000      51.000000
# 75%            76.000000            76.000000       76.000000      76.000000
# max           100.000000           100.000000      100.000000     100.000000
#
#        participant_count
# count      800000.000000
# mean           50.531509
# std            28.875802
# min             1.000000
# 25%            26.000000
# 50%            51.000000
# 75%            76.000000
# max           100.000000
# school_name                            0
# year                                   0
# StudentID                              0
# First Name                             0
# Last Name                              0
# Year Level                             0
# Class                                  0
# Subject                                0
# Answers                                0
# Correct Answers                        0
# Question Number                        0
# Subject Contents                       0
# Assessment Areas                       0
# sydney_correct_count_percentage        0
# sydney_average_score                   0
# sydney_participants                    0
# student_score                          0
# student_total_assessed                 0
# student_area_assessed_score            0
# total_area_assessed_score              0
# participant                            0
# correct_answer_percentage_per_class    0
# average_score                          0
# school_percentile                      0
# sydney_percentile                      0
# strength_status                        0
# high_distinct_count                    0
# distinct_count                         0
# credit_count                           0
# participant_count                      0
# award                                  0
# dtype: int64
# 0
